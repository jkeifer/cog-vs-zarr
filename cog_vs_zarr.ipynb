# %%
import json
import urllib.request

from hashlib import sha256
from pathlib import Path

import numpy as np
import rioxarray

from tifffile import TiffFile
from zarr import codecs

# %%
STAC_ITEM_HREF = "https://earth-search.aws.element84.com/v1/collections/sentinel-2-c1-l2a/items/S2B_T10TFR_20231223T190950_L2A"
#ASSETS = ['blue', 'green', 'red', 'nir']
ASSETS = ['red']

# %%
def hash_bytes(b: bytes) -> str:
    h = sha256()
    h.update(b)
    return h.digest().hex()

# %%
with urllib.request.urlopen(urllib.request.Request(STAC_ITEM_HREF)) as response:
    stac_item = json.loads(response.read())

# %%
stac_item
# Out:
# {'type': 'Feature',
#  'stac_version': '1.0.0',
#  'id': 'S2B_T10TFR_20231223T190950_L2A',
#  'properties': {'created': '2024-01-05T19:36:39.226Z',
#   'platform': 'sentinel-2b',
#   'constellation': 'sentinel-2',
#   'instruments': ['msi'],
#   'eo:cloud_cover': 1.251174,
#   'proj:epsg': 32610,
#   'proj:centroid': {'lat': 45.54146, 'lon': -121.01583},
#   'mgrs:utm_zone': 10,
#   'mgrs:latitude_band': 'T',
#   'mgrs:grid_square': 'FR',
#   'grid:code': 'MGRS-10TFR',
#   'view:azimuth': 261.58446495525544,
#   'view:incidence_angle': 4.470565438518265,
#   'view:sun_azimuth': 167.494432114129,
#   'view:sun_elevation': 20.050386200648404,
#   's2:tile_id': 'S2B_OPER_MSI_L2A_TL_2BPS_20231223T212404_A035503_T10TFR_N05.10',
#   's2:degraded_msi_data_percentage': 0.01,
#   's2:nodata_pixel_percentage': 3e-06,
#   's2:saturated_defective_pixel_percentage': 0,
#   's2:dark_features_percentage': 14.411107,
#   's2:cloud_shadow_percentage': 0.218994,
#   's2:vegetation_percentage': 27.606273,
#   's2:not_vegetated_percentage': 53.845996,
#   's2:water_percentage': 1.332295,
#   's2:unclassified_percentage': 0.01936,
#   's2:medium_proba_clouds_percentage': 0.102591,
#   's2:high_proba_clouds_percentage': 0.056529,
#   's2:thin_cirrus_percentage': 1.092053,
#   's2:snow_ice_percentage': 1.3148,
#   's2:product_type': 'S2MSI2A',
#   's2:processing_baseline': '05.10',
#   's2:product_uri': 'S2B_MSIL2A_20231223T190819_N0510_R013_T10TFR_20231223T212404.SAFE',
#   's2:generation_time': '2023-12-23T21:24:04.000000Z',
#   's2:datatake_id': 'GS2B_20231223T190819_035503_N05.10',
#   's2:datatake_type': 'INS-NOBS',
#   's2:datastrip_id': 'S2B_OPER_MSI_L2A_DS_2BPS_20231223T212404_S20231223T190950_N05.10',
#   's2:reflectance_conversion_factor': 1.03315307963847,
#   'datetime': '2023-12-23T19:11:53.327000Z',
#   'earthsearch:payload_id': 'roda-sentinel-2-c1-l2a/workflow-sentinel-2-c1-l2a-to-stac/e33d540896e8b5309c6425442562899c',
#   'storage:platform': 'AWS',
#   'storage:region': 'us-west-2',
#   'storage:requester_pays': False,
#   'processing:software': {'sentinel-2-c1-l2a-to-stac': 'v2023.12.01'},
#   'updated': '2024-01-05T19:36:39.226Z'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-121.70745525207822, 46.046256311703836],
#     [-121.7299114313325, 45.05820617850736],
#     [-120.33650805653772, 45.03419942789321],
#     [-120.28946919707845, 46.02141305809806],
#     [-121.70745525207822, 46.046256311703836]]]},
#  'links': [{'rel': 'self',
#    'type': 'application/geo+json',
#    'href': 'https://earth-search.aws.element84.com/v1/collections/sentinel-2-c1-l2a/items/S2B_T10TFR_20231223T190950_L2A'},
#   {'rel': 'canonical',
#    'href': 's3://e84-earth-search-sentinel-data/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/S2B_T10TFR_20231223T190950_L2A.json',
#    'type': 'application/json'},
#   {'rel': 'via',
#    'href': 's3://sentinel-s2-l2a/tiles/10/T/FR/2023/12/23/0/metadata.xml',
#    'type': 'application/xml',
#    'title': 'Granule Metadata in Sinergize RODA Archive'},
#   {'rel': 'parent',
#    'type': 'application/json',
#    'href': 'https://earth-search.aws.element84.com/v1/collections/sentinel-2-c1-l2a'},
#   {'rel': 'collection',
#    'type': 'application/json',
#    'href': 'https://earth-search.aws.element84.com/v1/collections/sentinel-2-c1-l2a'},
#   {'rel': 'root',
#    'type': 'application/json',
#    'href': 'https://earth-search.aws.element84.com/v1'},
#   {'rel': 'thumbnail',
#    'href': 'https://earth-search.aws.element84.com/v1/collections/sentinel-2-c1-l2a/items/S2B_T10TFR_20231223T190950_L2A/thumbnail'}],
#  'assets': {'red': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B04.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Red - 10m',
#    'eo:bands': [{'name': 'B04',
#      'common_name': 'red',
#      'center_wavelength': 0.665,
#      'full_width_half_max': 0.038}],
#    'gsd': 10,
#    'proj:shape': [10980, 10980],
#    'proj:transform': [10, 0, 600000, 0, -10, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 10,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '12206ff19969cfb660ae0a68694c14330db2b8a221d2a7298a9857432dc71838a9a0',
#    'file:size': 218693282,
#    'roles': ['data', 'reflectance']},
#   'green': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B03.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Green - 10m',
#    'eo:bands': [{'name': 'B03',
#      'common_name': 'green',
#      'center_wavelength': 0.56,
#      'full_width_half_max': 0.045}],
#    'gsd': 10,
#    'proj:shape': [10980, 10980],
#    'proj:transform': [10, 0, 600000, 0, -10, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 10,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '1220eb02f96cf6abc20b50d99c7cbcddb1c405c74dea2cf9cf5231c7c3dc4eed565b',
#    'file:size': 218672752,
#    'roles': ['data', 'reflectance']},
#   'blue': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B02.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Blue - 10m',
#    'eo:bands': [{'name': 'B02',
#      'common_name': 'blue',
#      'center_wavelength': 0.49,
#      'full_width_half_max': 0.098}],
#    'gsd': 10,
#    'proj:shape': [10980, 10980],
#    'proj:transform': [10, 0, 600000, 0, -10, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 10,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '12200e61d651cee6f2579084f5a233531458c4c66d0bc2f5a2645e087bad36ebdcd6',
#    'file:size': 214310547,
#    'roles': ['data', 'reflectance']},
#   'visual': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/TCI.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'True color image',
#    'eo:bands': [{'name': 'B04',
#      'common_name': 'red',
#      'center_wavelength': 0.665,
#      'full_width_half_max': 0.038},
#     {'name': 'B03',
#      'common_name': 'green',
#      'center_wavelength': 0.56,
#      'full_width_half_max': 0.045},
#     {'name': 'B02',
#      'common_name': 'blue',
#      'center_wavelength': 0.49,
#      'full_width_half_max': 0.098}],
#    'gsd': 10,
#    'proj:shape': [10980, 10980],
#    'proj:transform': [10, 0, 600000, 0, -10, 5100000],
#    'file:checksum': '12202131da98887d4009bee379988d5b285e71740f7220e21104886976f74cbc1a09',
#    'file:size': 303733095,
#    'roles': ['visual']},
#   'nir': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B08.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'NIR 1 - 10m',
#    'eo:bands': [{'name': 'B08',
#      'common_name': 'nir',
#      'center_wavelength': 0.842,
#      'full_width_half_max': 0.145}],
#    'gsd': 10,
#    'proj:shape': [10980, 10980],
#    'proj:transform': [10, 0, 600000, 0, -10, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 10,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '12207f653b35b428798d247b984ba8b922e11f2f04836c9c483945c6f61a26b1cb85',
#    'file:size': 242246558,
#    'roles': ['data', 'reflectance']},
#   'swir22': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B12.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'SWIR 2.2μm - 20m',
#    'eo:bands': [{'name': 'B12',
#      'common_name': 'swir22',
#      'center_wavelength': 2.19,
#      'full_width_half_max': 0.242}],
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '12204e5d21ead018558aa353637832c6df02503a8d1012611129b80a153c4dc8a2a8',
#    'file:size': 56587139,
#    'roles': ['data', 'reflectance']},
#   'rededge2': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B06.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Red Edge 2 - 20m',
#    'eo:bands': [{'name': 'B06',
#      'common_name': 'rededge',
#      'center_wavelength': 0.74,
#      'full_width_half_max': 0.018}],
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '12204588ab518e3f33756d62b81e7232bc0294e23ced2f2865c759e24478475f1efd',
#    'file:size': 60681238,
#    'roles': ['data', 'reflectance']},
#   'rededge3': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B07.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Red Edge 3 - 20m',
#    'eo:bands': [{'name': 'B07',
#      'common_name': 'rededge',
#      'center_wavelength': 0.783,
#      'full_width_half_max': 0.028}],
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '12202399c1e130b10b135508165585d7427bd4fa974c286e8a50e234a32c4621893f',
#    'file:size': 61207030,
#    'roles': ['data', 'reflectance']},
#   'rededge1': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B05.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Red Edge 1 - 20m',
#    'eo:bands': [{'name': 'B05',
#      'common_name': 'rededge',
#      'center_wavelength': 0.704,
#      'full_width_half_max': 0.019}],
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '122010bd22786fa55a62a47f035810be40c4a03edbcf05b0699565ec10fbe0abf52c',
#    'file:size': 57731634,
#    'roles': ['data', 'reflectance']},
#   'swir16': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B11.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'SWIR 1.6μm - 20m',
#    'eo:bands': [{'name': 'B11',
#      'common_name': 'swir16',
#      'center_wavelength': 1.61,
#      'full_width_half_max': 0.143}],
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '1220fcbb9b8c12dd5971f3582ec56637fcb35613063569c73ce430bd3915fd22c6c4',
#    'file:size': 58467077,
#    'roles': ['data', 'reflectance']},
#   'wvp': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/WVP.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Water Vapour (WVP)',
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'unit': 'cm',
#      'scale': 0.001,
#      'offset': 0}],
#    'file:checksum': '1220a32e784638b2b53bcf7f64b161b162afd0a85397991f48f434711af3dc1a8f5d',
#    'file:size': 42558253,
#    'roles': ['data']},
#   'nir08': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B8A.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'NIR 2 - 20m',
#    'eo:bands': [{'name': 'B8A',
#      'common_name': 'nir08',
#      'center_wavelength': 0.865,
#      'full_width_half_max': 0.033}],
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '122066ef5acd140ee62ceceb60f238443c3ad4004f911e119ba0054ed40cdc7e749d',
#    'file:size': 61449571,
#    'roles': ['data', 'reflectance']},
#   'scl': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/SCL.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Scene classification map (SCL)',
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint8',
#      'spatial_resolution': 20}],
#    'file:checksum': '1220cd640365c593f744eeb7b0a8a5b7f66157d06e43cb4f80cbdf39f9507915a8cb',
#    'file:size': 3077167,
#    'roles': ['data']},
#   'aot': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/AOT.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Aerosol optical thickness (AOT)',
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 20,
#      'scale': 0.001,
#      'offset': 0}],
#    'file:checksum': '1220acf5f2c6389f16bdd5ccc980ece525d8bf58a7bc4cc94cd94db2208b5b064e07',
#    'file:size': 2163428,
#    'roles': ['data']},
#   'coastal': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B01.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Coastal - 60m',
#    'eo:bands': [{'name': 'B01',
#      'common_name': 'coastal',
#      'center_wavelength': 0.443,
#      'full_width_half_max': 0.027}],
#    'gsd': 60,
#    'proj:shape': [1830, 1830],
#    'proj:transform': [60, 0, 600000, 0, -60, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 60,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '1220235609894d755c3b8b75001589e26c727c311021f46005292239d13b5121a1bf',
#    'file:size': 5879279,
#    'roles': ['data', 'reflectance']},
#   'nir09': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B09.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'NIR 3 - 60m',
#    'eo:bands': [{'name': 'B09',
#      'common_name': 'nir09',
#      'center_wavelength': 0.945,
#      'full_width_half_max': 0.026}],
#    'gsd': 60,
#    'proj:shape': [1830, 1830],
#    'proj:transform': [60, 0, 600000, 0, -60, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint16',
#      'spatial_resolution': 60,
#      'scale': 0.0001,
#      'offset': -0.1}],
#    'file:checksum': '1220892c9102b207f77fcb9cbe974fb50ace65826ba7f60f753994f5126f8f37d75a',
#    'file:size': 6838745,
#    'roles': ['data', 'reflectance']},
#   'cloud': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/CLD_20m.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Cloud Probabilities',
#    'gsd': 20,
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint8',
#      'spatial_resolution': 20}],
#    'file:checksum': '12208e662320e5fb7ef4674fce5b11e0b00e88edf1f1e8da529996452de739551639',
#    'file:size': 872631,
#    'roles': ['data', 'cloud']},
#   'snow': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/SNW_20m.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'Snow Probabilities',
#    'proj:shape': [5490, 5490],
#    'proj:transform': [20, 0, 600000, 0, -20, 5100000],
#    'raster:bands': [{'nodata': 0,
#      'data_type': 'uint8',
#      'spatial_resolution': 20}],
#    'file:checksum': '1220b233cda3f099e0d0eb80477a647d207d1e577ad82064b6cfe61c7f284c234569',
#    'file:size': 392369,
#    'roles': ['data', 'snow-ice']},
#   'preview': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/L2A_PVI.tif',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'title': 'True color preview',
#    'eo:bands': [{'name': 'B04',
#      'common_name': 'red',
#      'center_wavelength': 0.665,
#      'full_width_half_max': 0.038},
#     {'name': 'B03',
#      'common_name': 'green',
#      'center_wavelength': 0.56,
#      'full_width_half_max': 0.045},
#     {'name': 'B02',
#      'common_name': 'blue',
#      'center_wavelength': 0.49,
#      'full_width_half_max': 0.098}],
#    'file:checksum': '122063502344e46d049a7e61a70d2f8c9390b301f02288c63e63076df5360cf878c1',
#    'file:size': 191129,
#    'roles': ['overview']},
#   'granule_metadata': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/metadata.xml',
#    'type': 'application/xml',
#    'file:checksum': '1220b7ae2954a28bbffa515bdc1ef564d2746f8b66815f0f6d82b3f8b625f20ad276',
#    'file:size': 547816,
#    'roles': ['metadata']},
#   'tileinfo_metadata': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/tileInfo.json',
#    'type': 'application/json',
#    'file:checksum': '1220d3b6ba8fce5983fb4b720f44ea206434629d376f980b8c8e32e984b649acf95d',
#    'file:size': 1494,
#    'roles': ['metadata']},
#   'product_metadata': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/product_metadata.xml',
#    'type': 'application/xml',
#    'file:checksum': '12201f00075ad881aa17ac94bf8f9eebee078ffa22853f4aa0781ff6375d0decd2b6',
#    'file:size': 54358,
#    'roles': ['metadata']},
#   'thumbnail': {'href': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/L2A_PVI.jpg',
#    'type': 'image/jpeg',
#    'title': 'Thumbnail of preview image',
#    'file:checksum': '12204d938f82ec2857e97d640cee094ca54a4ef10b901cbf6c7a6ae91d7b147183b6',
#    'file:size': 30299,
#    'roles': ['thumbnail']}},
#  'bbox': [-121.729911, 45.034199, -120.289469, 46.046256],
#  'stac_extensions': ['https://stac-extensions.github.io/eo/v1.1.0/schema.json',
#   'https://stac-extensions.github.io/file/v2.1.0/schema.json',
#   'https://stac-extensions.github.io/grid/v1.1.0/schema.json',
#   'https://stac-extensions.github.io/mgrs/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/processing/v1.1.0/schema.json',
#   'https://stac-extensions.github.io/projection/v1.1.0/schema.json',
#   'https://stac-extensions.github.io/raster/v1.1.0/schema.json',
#   'https://stac-extensions.github.io/sentinel-2/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/storage/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/view/v1.0.0/schema.json'],
#  'collection': 'sentinel-2-c1-l2a'}

# %%
cog_hrefs = {name: asset['href'] for name, asset in stac_item['assets'].items() if name in ASSETS}
cog_hrefs
# Out:
# {'red': 'https://e84-earth-search-sentinel-data.s3.us-west-2.amazonaws.com/sentinel-2-c1-l2a/10/T/FR/2023/12/S2B_T10TFR_20231223T190950_L2A/B04.tif'}

# %%
test_data = Path('test_data')
test_data.mkdir(exist_ok=True)

# %%
for name, href in cog_hrefs.items():
    file_name = test_data / (name + '.tif')
    
    if file_name.exists():
        continue

    with urllib.request.urlopen(urllib.request.Request(href)) as response:
        (test_data / (name + '.tif')).write_bytes(response.read())

# %%
tags = {}
with TiffFile(test_data/'red.tif') as tif:
    for tag in tif.pages[0].tags:
        tag_name, tag_value = tag.name, tag.value
        tags[tag_name] = tag_value
        print(tag_name, tag_value)
# Out:
# ImageWidth 10980
# ImageLength 10980
# BitsPerSample 16
# Compression 8
# PhotometricInterpretation 1
# SamplesPerPixel 1
# PlanarConfiguration 1
# Predictor 2
# TileWidth 1024
# TileLength 1024
# TileOffsets (55962680, 57411167, 58810332, 60222446, 61651003, 63054996, 64463518, 66025043, 67523672, 68987825, 70439668, 71480485, 72831139, 74191906, 75556803, 76922917, 78346396, 79767466, 81177106, 82626646, 84045343, 85436959, 86443457, 87744763, 89128625, 90516041, 91896145, 93323921, 94699513, 96054131, 97398784, 98768288, 100117176, 101099165, 102475360, 103914015, 105337327, 106767167, 108155055, 109496290, 110853634, 112244713, 113588526, 114895196, 115881834, 117297939, 118737048, 120185270, 121620456, 123031867, 124402930, 125797422, 127166585, 128512496, 129847193, 130813023, 132267746, 133721219, 135168258, 136590051, 138004961, 139387400, 140792216, 142173401, 143531515, 144883653, 145909014, 147512228, 148965842, 150393926, 151820955, 153228408, 154629691, 156014882, 157380367, 158731976, 160114338, 161151032, 162782880, 164279805, 165702744, 167136236, 168547793, 169940007, 171321112, 172637466, 174003270, 175392224, 176416464, 178052532, 179640701, 181092961, 182534128, 183924802, 185311293, 186651878, 187954039, 189327902, 190698439, 191714854, 193331795, 194939195, 196415899, 197819251, 199217398, 200625142, 201991437, 203345078, 204717082, 206137392, 207171477, 208347309, 209482357, 210584255, 211625167, 212683632, 213739512, 214787222, 215844136, 216879023, 217929856)
# TileByteCounts (1448479, 1399157, 1412106, 1428549, 1403985, 1408514, 1561517, 1498621, 1464145, 1451835, 1040809, 1350646, 1360759, 1364889, 1366106, 1423471, 1421062, 1409632, 1449532, 1418689, 1391608, 1006490, 1301298, 1383854, 1387408, 1380096, 1427768, 1375584, 1354610, 1344645, 1369496, 1348880, 981981, 1376187, 1438647, 1423304, 1429832, 1387880, 1341227, 1357336, 1391071, 1343805, 1306662, 986630, 1416097, 1439101, 1448214, 1435178, 1411403, 1371055, 1394484, 1369155, 1345903, 1334689, 965822, 1454715, 1453465, 1447031, 1421785, 1414902, 1382431, 1404808, 1381177, 1358106, 1352130, 1025353, 1603206, 1453606, 1428076, 1427021, 1407445, 1401275, 1385183, 1365477, 1351601, 1382354, 1036686, 1631840, 1496917, 1422931, 1433484, 1411549, 1392206, 1381097, 1316346, 1365796, 1388946, 1024232, 1636060, 1588161, 1452252, 1441159, 1390666, 1386483, 1340577, 1302153, 1373855, 1370529, 1016407, 1616933, 1607392, 1476696, 1403344, 1398139, 1407736, 1366287, 1353633, 1371996, 1420302, 1034077, 1175824, 1135040, 1101890, 1040904, 1058457, 1055872, 1047702, 1056906, 1034879, 1050825, 763422)
# SampleFormat 1
# ModelPixelScaleTag (10.0, 10.0, 0.0)
# ModelTiepointTag (0.0, 0.0, 0.0, 600000.0, 5100000.0, 0.0)
# GeoKeyDirectoryTag (1, 1, 0, 7, 1024, 0, 1, 1, 1025, 0, 1, 1, 1026, 34737, 22, 0, 2049, 34737, 7, 22, 2054, 0, 1, 9102, 3072, 0, 1, 32610, 3076, 0, 1, 9001)
# GeoAsciiParamsTag WGS 84 / UTM zone 10N|WGS 84|
# GDAL_METADATA <GDALMetadata>
#   <Item name="OVR_RESAMPLING_ALG">AVERAGE</Item>
#   <Item name="STATISTICS_MAXIMUM" sample="0">17408</Item>
#   <Item name="STATISTICS_MEAN" sample="0">1505.1947339533</Item>
#   <Item name="STATISTICS_MINIMUM" sample="0">294</Item>
#   <Item name="STATISTICS_STDDEV" sample="0">659.24503616433</Item>
#   <Item name="STATISTICS_VALID_PERCENT" sample="0">99.999</Item>
#   <Item name="OFFSET" sample="0" role="offset">-0.100000000000000006</Item>
#   <Item name="SCALE" sample="0" role="scale">0.000100000000000000005</Item>
# </GDALMetadata>
# GDAL_NODATA 0

# %%
with (test_data/'red.tif').open('rb') as tif:
    tif.seek(55962680)
    print(hash_bytes(tif.read(1448479)))
# Out:
# 2c02e7e60074d6767ccb4c44de2da249d331fd82e107431e41cfe4069bae0d62

# %%
ds = rioxarray.open_rasterio(test_data/'red.tif').to_dataset(name='red')

# %%
ds
# Out:
# <xarray.Dataset> Size: 241MB
# Dimensions:      (band: 1, x: 10980, y: 10980)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 6e+05 6e+05 6e+05 ... 7.098e+05 7.098e+05
#   * y            (y) float64 88kB 5.1e+06 5.1e+06 5.1e+06 ... 4.99e+06 4.99e+06
#     spatial_ref  int64 8B 0
# Data variables:
#     red          (band, y, x) uint16 241MB ...

# %%
ds.to_zarr(
    test_data/'zarr',
    zarr_format=3,
    encoding={
        'red': {
            "chunks": (1, 1024, 1024),
        },
    },
    safe_chunks=False,
)
# Out:
# /Users/jkeifer/dev/cng-raster-formats/.direnv/python-3.12/lib/python3.12/site-packages/zarr/api/asynchronous.py:205: UserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
import zlib

# %%
with (test_data/'red.tif').open('rb') as tif:
    tif.seek(55962680)
    tile_bytes = tif.read(1448479)

# %%
len(tile_bytes)
# Out:
# 1448479

# %%
zlib.decompress(tile_bytes, 0)

# %%
zstd_codec = codecs.ZstdCodec()

# %%
from numcodecs.zstd import Zstd

from io import BytesIO

# %%
zstd = Zstd()

# %%
zstd_tile = zstd.encode(zlib.decompress(tile_bytes, 0))

# %%
zstd_tile = zstd.encode(np.cumsum(np.frombuffer(zlib.decompress(tile_bytes, 0), dtype=np.uint16).reshape(1024, 1024), axis=1, dtype=np.uint16).tobytes())

# %%
len(zstd_tile)
print(len(zstd_tile))
print(hash_bytes(zstd_tile))
# Out:
# 1454273
# 6bad8a3594bbdf9300c7f823a5969ece06d6f596d9139908c2f01de51e564af8

# %%
with (test_data/'zarr'/'red'/'c'/'0'/'0'/'0').open('rb') as fh:
    zarr_tile_bytes = fh.read()

# %%
print(len(zarr_tile_bytes))
print(hash_bytes(zarr_tile_bytes))
# Out:
# 1454273
# 6bad8a3594bbdf9300c7f823a5969ece06d6f596d9139908c2f01de51e564af8

# %%
import xarray
ds2 = xarray.open_dataset(test_data/'zarr', engine='zarr')

# %%
ds2
# Out:
# <xarray.Dataset> Size: 965MB
# Dimensions:      (band: 1, x: 10980, y: 10980)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 88kB 6e+05 6e+05 6e+05 ... 7.098e+05 7.098e+05
#   * y            (y) float64 88kB 5.1e+06 5.1e+06 5.1e+06 ... 4.99e+06 4.99e+06
# Data variables:
#     spatial_ref  int64 8B ...
#     red          (band, y, x) float64 964MB ...

# %%
ds2['red'].encoding
# Out:
# {'chunks': (1, 1024, 1024),
#  'preferred_chunks': {'band': 1, 'y': 1024, 'x': 1024},
#  'compressors': (ZstdCodec(level=0, checksum=False),),
#  'filters': (),
#  'shards': None,
#  'serializer': BytesCodec(endian=<Endian.little: 'little'>),
#  '_FillValue': 0,
#  'scale_factor': 0.0001,
#  'add_offset': -0.1,
#  'dtype': dtype('uint16')}
